# %% [markdown]
# # Importing Libraries

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# for Q-Q plots
import scipy.stats as stats
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve

# %matplotlib inline

# %% [markdown]
# # Loading Dataset

# %%
# Loading dataset
data =  pd.read_csv("hiring_assignment_cv.csv")

# making copy of original data, we will perform our operations on the copy
df = data.copy()
df.shape
# Out:
# (25356, 69)

# %%
df.head(5)
# Out:
#    uuid  y  v1   v2        v3        v4  v5  v6  v7        v8  ...       v58  \
# 0  1001  0   3  1.0  0.072289  0.000000   0   5   1  2.250000  ...  2.119686
# 1  1002  0   1  1.0  0.052632  0.000000   1   5   0  1.666667  ...  2.049976
# 2  1003  0   1  2.0  0.138158  0.055556   2   5   0  3.750000  ...  4.163819
# 3  1004  0   0  0.0  0.082474  0.018868   0   2   0  0.250000  ...  0.792426
# 4  1005  0   1  1.5  0.000000  0.051282   1   3   1  1.750000  ...  1.074042
#
#         v59       v60       v61       v62       v63       v64       v65  \
# 0  0.416667  0.520833  0.428571  0.227273  0.837209  1.000000  0.757009
# 1  0.166667  0.500000  0.000000  0.428571  0.500000  1.000000  0.352941
# 2  0.298246  0.631579  0.055556  0.000000  0.333333  0.400000  0.196262
# 3  0.272727  0.613636  0.083333  0.034483  0.756757  0.972973  0.673077
# 4  0.152174  0.760870  0.000000  0.000000  0.700000  0.875000  0.654206
#
#         v66  v67
# 0  0.757009  3.0
# 1  0.352941  1.0
# 2  0.196262  7.0
# 3  0.673077  7.0
# 4  0.654206  8.0
#
# [5 rows x 69 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25356 entries, 0 to 25355
# Data columns (total 69 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   uuid    25356 non-null  int64
#  1   y       25356 non-null  int64
#  2   v1      25356 non-null  int64
#  3   v2      25356 non-null  float64
#  4   v3      25356 non-null  float64
#  5   v4      25356 non-null  float64
#  6   v5      25356 non-null  int64
#  7   v6      25356 non-null  int64
#  8   v7      25356 non-null  int64
#  9   v8      25356 non-null  float64
#  10  v9      25356 non-null  float64
#  11  v10     25356 non-null  float64
#  12  v11     25356 non-null  float64
#  13  v12     25356 non-null  float64
#  14  v13     25356 non-null  int64
#  15  v14     25356 non-null  float64
#  16  v15     25356 non-null  float64
#  17  v16     25356 non-null  float64
#  18  v17     25356 non-null  float64
#  19  v18     25356 non-null  float64
#  20  v19     25356 non-null  float64
#  21  v20     25356 non-null  float64
#  22  v21     25356 non-null  float64
#  23  v22     25356 non-null  float64
#  24  v23     25356 non-null  float64
#  25  v24     25356 non-null  float64
#  26  v25     25356 non-null  float64
#  27  v26     25356 non-null  float64
#  28  v27     25356 non-null  float64
#  29  v28     25356 non-null  float64
#  30  v29     25356 non-null  float64
#  31  v30     25356 non-null  float64
#  32  v31     25356 non-null  float64
#  33  v32     25356 non-null  float64
#  34  v33     25356 non-null  float64
#  35  v34     25356 non-null  float64
#  36  v35     25356 non-null  float64
#  37  v36     25356 non-null  float64
#  38  v37     25356 non-null  float64
#  39  v38     25356 non-null  float64
#  40  v39     25356 non-null  float64
#  41  v40     25356 non-null  float64
#  42  v41     25356 non-null  float64
#  43  v42     25356 non-null  float64
#  44  v43     25356 non-null  int64
#  45  v44     25356 non-null  int64
#  46  v45     25356 non-null  int64
#  47  v46     25356 non-null  int64
#  48  v47     25356 non-null  int64
#  49  v48     25356 non-null  int64
#  50  v49     25356 non-null  float64
#  51  v50     25356 non-null  float64
#  52  v51     25356 non-null  float64
#  53  v52     25356 non-null  float64
#  54  v53     25356 non-null  float64
#  55  v54     25356 non-null  float64
#  56  v55     25356 non-null  float64
#  57  v56     25356 non-null  float64
#  58  v57     25356 non-null  float64
#  59  v58     25356 non-null  float64
#  60  v59     25356 non-null  float64
#  61  v60     25356 non-null  float64
#  62  v61     25356 non-null  float64
#  63  v62     25356 non-null  float64
#  64  v63     25356 non-null  float64
#  65  v64     25356 non-null  float64
#  66  v65     25356 non-null  float64
#  67  v66     25356 non-null  float64
#  68  v67     25356 non-null  float64
# dtypes: float64(56), int64(13)
# memory usage: 13.3 MB

# %% [markdown]
# ### Observations
# - uuid is id column and can be drop
# - dtypes of columns are either int64, float64 (need to explore more to see the ordinal behavior of features)
# - primarily it looks like there are no null values

# %% [markdown]
# # Data Pre-Processing

# %%
# dropping uuid column
df.drop(['uuid'],axis=1,inplace=True)

# %%
# finding duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# function to check missing value
def check_missing_value(data,col):
    ''' function will take dataframe and column name as input
     and will print missing values corresponding to each column '''
    print(col,df[col].isnull().sum())

# %%
# printing count of missing values corresponding to each column
for col in df.columns:
    check_missing_value(df,col)
# Out:
# y 0
# v1 0
# v2 0
# v3 0
# v4 0
# v5 0
# v6 0
# v7 0
# v8 0
# v9 0
# v10 0
# v11 0
# v12 0
# v13 0
# v14 0
# v15 0
# v16 0
# v17 0
# v18 0
# v19 0
# v20 0
# v21 0
# v22 0
# v23 0
# v24 0
# v25 0
# v26 0
# v27 0
# v28 0
# v29 0
# v30 0
# v31 0
# v32 0
# v33 0
# v34 0
# v35 0
# v36 0
# v37 0
# v38 0
# v39 0
# v40 0
# v41 0
# v42 0
# v43 0
# v44 0
# v45 0
# v46 0
# v47 0
# v48 0
# v49 0
# v50 0
# v51 0
# v52 0
# v53 0
# v54 0
# v55 0
# v56 0
# v57 0
# v58 0
# v59 0
# v60 0
# v61 0
# v62 0
# v63 0
# v64 0
# v65 0
# v66 0
# v67 0

# %%
# fucntion to check number of unique value present in each column
def unique_value(data,col):
    ''' function will take dataframe and column name as input
     and will print unique values corresponding to each column '''
    
    print(col,data[col].nunique())

# %%
# printing number of unique values corresponding to each column
for col in df.columns:
    unique_value(df,col)
# Out:
# y 2
# v1 7
# v2 97
# v3 1179
# v4 1094
# v5 3
# v6 6
# v7 5
# v8 111
# v9 25
# v10 15
# v11 1200
# v12 405
# v13 2
# v14 213
# v15 238
# v16 4737
# v17 20588
# v18 19194
# v19 7138
# v20 2374
# v21 5404
# v22 8931
# v23 3789
# v24 319
# v25 7389
# v26 20674
# v27 1110
# v28 1213
# v29 7049
# v30 21669
# v31 2365
# v32 71
# v33 237
# v34 116
# v35 10
# v36 2528
# v37 1090
# v38 10
# v39 53
# v40 247
# v41 48
# v42 2568
# v43 1
# v44 1
# v45 1
# v46 1
# v47 1
# v48 1
# v49 9
# v50 19844
# v51 22514
# v52 21273
# v53 21235
# v54 21268
# v55 21020
# v56 21401
# v57 21347
# v58 21488
# v59 1249
# v60 1377
# v61 317
# v62 632
# v63 1293
# v64 1266
# v65 3733
# v66 3733
# v67 10

# %% [markdown]
# #### Observations
# - There are no duplicate values
# - There are no missing values

# %% [markdown]
# ### Splitting Dataset into two datframes (Dependent and Independent Variable)a

# %%
# Splitting the data frame based on dependent and independent variable
# in our case 'y' is our target column
X_raw = df.drop(['y'],axis=1)
y= df[['y']]

# %%
X_raw.shape
# Out:
# (25356, 67)

# %%
# Peeking into the data of first 20 columns
X_raw[X_raw.columns[0:20]].head()
# Out:
#    v1   v2        v3        v4  v5  v6  v7        v8        v9       v10  \
# 0   3  1.0  0.072289  0.000000   0   5   1  2.250000  0.750000  0.500000
# 1   1  1.0  0.052632  0.000000   1   5   0  1.666667  0.666667  0.666667
# 2   1  2.0  0.138158  0.055556   2   5   0  3.750000  2.500000  1.000000
# 3   0  0.0  0.082474  0.018868   0   2   0  0.250000  0.250000  0.000000
# 4   1  1.5  0.000000  0.051282   1   3   1  1.750000  0.250000  0.250000
#
#         v11       v12  v13        v14       v15       v16            v17  \
# 0  0.072289  0.000000    1   9.000000  3.166667  0.696970   -2473.422577
# 1  0.052632  0.000000    1   5.000000  3.609587  0.234694    -511.942258
# 2  0.140000  0.053333    1  34.333333  5.833333  0.279412 -100909.290100
# 3  0.082474  0.000000    0  39.333333  6.000000  0.380952    5522.287579
# 4  0.000000  0.000000    1  34.666667  4.000000  0.356604  -49590.867140
#
#         v18       v19       v20
# 0  0.011237  0.605405  0.526316
# 1  0.034617  0.495902  0.288462
# 2  0.000810  0.505814  0.500000
# 3  0.000000  0.604167  0.454545
# 4  0.000317  0.680504  0.258985

# %%
# Peeking into the data of next 20 columns
X_raw[X_raw.columns[20:40]].head()
# Out:
#          v21       v22       v23          v24       v25       v26        v27  \
# 0  16.578947  0.231746  0.785047   8569.00000  5.875000  2.189692  18.250000
# 1  25.600000  0.480469  0.352941  16790.00000  7.018160  2.049976  41.000000
# 2   2.943396  0.769670  0.112150   9399.00000  4.161508  2.973970  18.888889
# 3  16.714286  0.162393  0.846154  14447.90638  4.291667  0.775067  14.250000
# 4  23.580120  0.264931  0.308411  14447.90638  4.818254  5.057200  23.347984
#
#         v28       v29        v30       v31        v32        v33        v34  \
# 0  1.000000  0.651786    2424.36  0.048000   4.666667  12.000000   5.333333
# 1  1.000000  1.016529     490.67  0.092000   0.000000   6.000000   2.000000
# 2  0.277778  0.977011  153959.51  0.110000  10.666667  38.666667  23.333333
# 3  1.000000  0.655172   29798.68  0.062626   6.000000  39.000000   9.666667
# 4  0.850000  0.519292  107199.70  0.038554   7.000000  46.666667  19.666667
#
#         v35       v36       v37  v38       v39        v40
# 0  7.000000  0.273973  0.409091 -2.0  24.00000   9.800000
# 1  7.000000  0.308943  0.218182 -4.0  27.00000  21.200000
# 2  8.000000  0.211765  0.262821  4.0  54.00000  25.400000
# 3  6.000000  0.578947  0.280000  1.0   9.00000   9.800000
# 4  4.465064  0.350324  0.200000 -2.0  28.35022  10.186421

# %%
# Peeking into the data of first remaining columns
X_raw[X_raw.columns[40:]].head()
# Out:
#         v41       v42  v43  v44  v45  v46  v47  v48       v49       v50  ...  \
# 0  24.00000  0.273973    0    0    0    0    0    0  0.714286  0.155855  ...
# 1  46.00000  0.308943    0    0    0    0    0    0  0.714286  0.266844  ...
# 2  46.00000  0.211765    0    0    0    0    0    0  0.714286  0.313234  ...
# 3  31.00000  0.621622    0    0    0    0    0    0  0.714286  0.143281  ...
# 4  18.22623  0.349309    0    0    0    0    0    0  0.721683  0.137439  ...
#
#         v58       v59       v60       v61       v62       v63       v64  \
# 0  2.119686  0.416667  0.520833  0.428571  0.227273  0.837209  1.000000
# 1  2.049976  0.166667  0.500000  0.000000  0.428571  0.500000  1.000000
# 2  4.163819  0.298246  0.631579  0.055556  0.000000  0.333333  0.400000
# 3  0.792426  0.272727  0.613636  0.083333  0.034483  0.756757  0.972973
# 4  1.074042  0.152174  0.760870  0.000000  0.000000  0.700000  0.875000
#
#         v65       v66  v67
# 0  0.757009  0.757009  3.0
# 1  0.352941  0.352941  1.0
# 2  0.196262  0.196262  7.0
# 3  0.673077  0.673077  7.0
# 4  0.654206  0.654206  8.0
#
# [5 rows x 27 columns]

# %%
y.tail()
# Out:
#        y
# 25351  0
# 25352  0
# 25353  0
# 25354  1
# 25355  0

# %%
# Checking the event rate
y.mean()
# Out:
# y    0.059079
# dtype: float64

# %%
# checking the distinct count of values in target column
y.y.value_counts()
# Out:
# 0    23858
# 1     1498
# Name: y, dtype: int64

# %%
# visualizing target column distribution
fig, axs = plt.subplots(1,2,figsize=(14,7))
sns.countplot(x='y',data=y,ax=axs[0])
axs[0].set_title("Frequency of each outcome")
y.y.value_counts().plot(x=None,y=None, kind='pie', ax=axs[1],autopct='%1.2f%%')
axs[1].set_title("Percentage of each outcome")
plt.show()

# %% [markdown]
# - Above plot shows we have more negative outcome than positive.
#     - we have made assumption that :
#        1 - Positive Outcome
#        0 - Negative outcome
# - Since output column has only two categories, we can treat it as a classification problem

# %%
# Removing columns that has just one value
X_raw = X_raw.loc[:,X_raw.apply(pd.Series.nunique) != 1]

# %%
X_raw.shape
# Out:
# (25356, 61)

# %%
# finding columns which has less than 10 unique values
columns_with_lt_10_values = []
for col in X_raw.columns:
    if (len(X_raw[col].unique()) < 10):
        columns_with_lt_10_values.append(col)
#         print(X_raw[col].value_counts())
columns_with_lt_10_values
# Out:
# ['v1', 'v5', 'v6', 'v7', 'v13', 'v49']

# %%
# function for visualizing the value_counts for each column 
def show_countplot(data,col):
    '''Fucntion will take and dataframe and column name as input
        O/p - Shows countplot
    
    '''
    
    # define figure size
    plt.figure(figsize=(16, 4))
    
    # countplot
    plt.subplot(1, 3, 1)
    sns.countplot(x= col, data=data, order=df[col].value_counts().index)
    plt.title('Countplot')
    
    plt.show()

# %%
# Plotting countplot for each value in columns_with_lt_10_values
for col in columns_with_lt_10_values:
    show_countplot(X_raw,col)

# %% [markdown]
# ### Observations
# - From above data we can observe that :
#     - Columns v1,v5,v6,v7 and v13 are having few distinct values and depicting some category-wise information. Hence these variables can be treated as categorical variables
#     - we can't say the same for v49 cause it contains continuous values

# %% [markdown]
# ### Splitting Dependent dataframe into categorical and numerical feature dataframes

# %%
# Splitting X_raw into categorical and Numerical features
cat_features = ['v1','v5','v6','v7','v13']
X_num = X_raw.drop(cat_features,axis=1)
X_cat = X_raw[cat_features]

# %%
X_num.shape
# Out:
# (25356, 56)

# %%
X_cat.shape
# Out:
# (25356, 5)

# %% [markdown]
# ### Here onwards we will process numerical and categorical features separately
# - X_num - Contains all the numerical features
# - X_cat - Contains all the categorical features

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Checking for number of rows having missing values
X_num.isnull().sum()
# Out:
# v2     0
# v3     0
# v4     0
# v8     0
# v9     0
# v10    0
# v11    0
# v12    0
# v14    0
# v15    0
# v16    0
# v17    0
# v18    0
# v19    0
# v20    0
# v21    0
# v22    0
# v23    0
# v24    0
# v25    0
# v26    0
# v27    0
# v28    0
# v29    0
# v30    0
# v31    0
# v32    0
# v33    0
# v34    0
# v35    0
# v36    0
# v37    0
# v38    0
# v39    0
# v40    0
# v41    0
# v42    0
# v49    0
# v50    0
# v51    0
# v52    0
# v53    0
# v54    0
# v55    0
# v56    0
# v57    0
# v58    0
# v59    0
# v60    0
# v61    0
# v62    0
# v63    0
# v64    0
# v65    0
# v66    0
# v67    0
# dtype: int64

# %% [markdown]
# ## Outlier Analysis Numerical Features

# %%
num_features = X_num.columns
len(num_features)
# Out:
# 56

# %%
# describing the numerical features percentile for first 20 numerical columns
X_num[num_features[0:20]].describe(percentiles=[0.01,0.05,0.10,0.25,0.50,0.75,0.80,0.9,0.99])
# Out:
#                  v2            v3            v4            v8            v9  \
# count  25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean       0.668034      0.043543      0.051626      1.251896      0.844074
# std        1.349966      0.059037      0.089443      1.944430      1.116940
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 1%         0.000000      0.000000      0.000000      0.000000      0.000000
# 5%         0.000000      0.000000      0.000000      0.000000      0.000000
# 10%        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.500000      0.333333
# 75%        0.750000      0.085959      0.081081      1.750000      1.250000
# 80%        1.000000      0.102564      0.105263      2.000000      1.500000
# 90%        2.000000      0.142857      0.174898      3.500000      2.666667
# 99%        6.250000      0.177563      0.388794      9.000000      4.000000
# max       24.250000      0.177563      1.000000     25.333333      4.000000
#
#                 v10           v11           v12           v14           v15  \
# count  25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean       0.419529      0.045043      0.004375     14.093725      3.431603
# std        0.659001      0.061307      0.013119     13.323202      2.458283
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 1%         0.000000      0.000000      0.000000      0.000000      1.000000
# 5%         0.000000      0.000000      0.000000      0.333333      1.000000
# 10%        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%        0.000000      0.000000      0.000000      4.333333      2.000000
# 50%        0.000000      0.000000      0.000000     10.000000      3.000000
# 75%        0.500000      0.087719      0.000000     19.333333      4.000000
# 80%        0.750000      0.105263      0.000000     22.666667      4.500000
# 90%        1.500000      0.147059      0.016949     33.333333      6.000000
# 99%        2.333333      0.190476      0.053333     53.000000     13.666667
# max        2.333333      0.190476      0.053333     53.000000     26.500000
#
#                 v16            v17           v18           v19           v20  \
# count  25356.000000   25356.000000  25356.000000  25356.000000  25356.000000
# mean       0.373634    3819.488870      0.146385      0.683323      0.196634
# std        0.241962   37422.248099      0.357838      0.130463      0.135430
# min        0.000000 -129089.417600      0.000000      0.294421      0.000000
# 1%         0.000000 -129089.417600      0.000000      0.294421      0.000000
# 5%         0.000000  -42808.971788      0.000000      0.427020      0.015625
# 10%        0.100879  -19718.758360      0.000000      0.500000      0.043669
# 25%        0.216667   -4915.030326      0.002886      0.611111      0.090909
# 50%        0.343750    -231.524048      0.035613      0.696841      0.171429
# 75%        0.480769    5852.063284      0.146783      0.780354      0.260870
# 80%        0.533333   11208.912280      0.152975      0.798165      0.295082
# 90%        0.704314   42178.088085      0.422125      0.840246      0.400000
# 99%        1.027778  110117.376900      1.000000      0.875570      0.526316
# max        1.027778  110117.376900     15.166660      0.875570      0.526316
#
#                 v21           v22           v23           v24           v25
# count  25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean      29.775572      0.263219      0.457789  14292.382671      7.069819
# std       20.214933      0.177888      0.269831   6275.222022      7.218507
# min        2.000000      0.032176      0.000000   5799.000000      0.000000
# 1%         2.000000      0.032176      0.000000   5799.000000      0.000000
# 5%         4.896552      0.067065      0.000000   6890.000000      0.000000
# 10%        7.658216      0.089744      0.120000   7990.000000      1.000000
# 25%       14.406818      0.137421      0.280374   9999.000000      3.500000
# 50%       24.000000      0.218045      0.435185  14447.906380      6.232044
# 75%       40.857143      0.327103      0.595798  15999.000000      8.464286
# 80%       46.000000      0.368000      0.666667  16790.000000      9.500000
# 90%       61.200000      0.517857      0.962963  21500.000000     12.972222
# 99%       79.000000      0.769670      0.988372  34900.000000     32.681667
# max       79.000000      0.769670      0.988372  34900.000000    216.000000

# %%
# we will try to visualize outliers with the help of boxplot,histograms,Q-Q plots,


def show_plots(df, variable):
    # function takes a dataframe (df) and variable name   

    # define figure size
    plt.figure(figsize=(16, 4))
    # boxplot
    plt.subplot(1, 3, 1)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    # histogram
    plt.subplot(1, 3, 2)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 3)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.ylabel('Variable quantiles')



    plt.show()

# %%
# visualizing for first 20 columns
for cols in X_num.columns[0:20]:
    show_plots(X_num, cols)

# %% [markdown]
# #### Columnwise Observations
#
# - Columns v2,v4,v8,v9,v10,v12,v14,v15,v16,v17,v18,v19,v20,v22,v24,v25 have outliers

# %%
# making list of columns with outliers
columns_with_outlier_1 = ['v2','v4','v8','v9','v10','v12','v14','v15','v16','v17','v18','v19','v20','v22','v22','v24','v25']

# %%
# describing the numerical features percentile for next 20 numerical columns
X_num[num_features[20:40]].describe(percentiles=[0.01,0.05,0.10,0.25,0.50,0.75,0.80,0.9,0.99])
# Out:
#                 v26           v27           v28           v29            v30  \
# count  25356.000000  25356.000000  25356.000000  25356.000000   25356.000000
# mean       1.592080     26.601066      0.746844      0.516281   46002.866261
# std        1.280585     17.772628      0.265001      0.331770   62434.247991
# min        0.049056      1.000000      0.000000      0.090909       8.662400
# 1%         0.049056      1.000000      0.000000      0.090909       8.662400
# 5%         0.187981      5.393750      0.153846      0.147541     706.422500
# 10%        0.353310      8.000000      0.400000      0.190127    1882.185000
# 25%        0.694809     13.794444      0.611111      0.281470    6298.252500
# 50%        1.324053     23.000000      0.789474      0.435047   21160.905000
# 75%        1.851202     34.666667      1.000000      0.636033   48913.045000
# 80%        2.185893     39.000000      1.000000      0.714286   64089.670000
# 90%        3.379040     54.000000      1.000000      0.991837  135677.580000
# 99%        5.459444     72.000000      1.000000      1.487452  239854.280000
# max        5.459444     72.000000      1.000000      1.487452  239854.280000
#
#                 v31           v32           v33           v34           v35  \
# count  25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean       0.044093      4.255401     16.616304      7.759643      3.130077
# std        0.026318      4.473108     15.546298      7.582688      2.510984
# min        0.000000      0.000000      0.333333      0.000000      0.000000
# 1%         0.000000      0.000000      0.333333      0.000000      0.000000
# 5%         0.010000      0.000000      1.000000      0.000000      0.000000
# 10%        0.014199      0.000000      2.000000      0.333333      0.000000
# 25%        0.024742      1.000000      5.000000      2.000000      1.000000
# 50%        0.038554      2.666667     11.666667      5.500000      3.000000
# 75%        0.058000      5.666667     23.000000     10.666667      5.000000
# 80%        0.064000      6.666667     27.000000     12.666667      5.000000
# 90%        0.083533     11.000000     41.000000     19.333333      7.000000
# 99%        0.110000     17.333333     59.000000     28.500000      8.000000
# max        0.110000     17.333333     59.000000     28.500000      8.000000
#
#                 v36           v37           v38           v39           v40  \
# count  25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean       0.269925      0.218759      0.035288     23.240058     10.942345
# std        0.141292      0.096171      1.749727     13.373622      5.980774
# min        0.016000      0.000000     -4.000000      3.000000      1.000000
# 1%         0.016000      0.000000     -4.000000      3.000000      1.000000
# 5%         0.070278      0.062500     -3.000000      6.000000      3.400000
# 10%        0.102273      0.090909     -2.000000      8.000000      4.500000
# 25%        0.161765      0.153846     -1.000000     13.000000      6.600000
# 50%        0.250000      0.221509      0.000000     21.000000     10.000000
# 75%        0.350324      0.281250      1.000000     30.000000     14.000000
# 80%        0.384615      0.302198      1.000000     33.000000     15.200000
# 90%        0.486486      0.355556      2.000000     44.000000     20.000000
# 99%        0.578947      0.409091      4.000000     54.000000     26.000000
# max        0.578947      0.409091      4.000000     54.000000     26.000000
#
#                 v41           v42           v49           v50            v51
# count  25356.000000  25356.000000  25356.000000  25356.000000   25356.000000
# mean      20.740419      0.271485      0.724256      0.135266   53567.858084
# std       11.958505      0.144468      0.102071      0.071566   75171.368872
# min        0.000000      0.023077      0.500000      0.020108       0.000000
# 1%         0.000000      0.023077      0.500000      0.020108       0.000000
# 5%         4.000000      0.070278      0.600000      0.041366     934.595000
# 10%        7.000000      0.102273      0.600000      0.055345    2267.065000
# 25%       12.000000      0.161765      0.714286      0.082532    7085.632500
# 50%       18.226230      0.250000      0.714286      0.123787   22895.695000
# 75%       28.000000      0.349309      0.721683      0.172000   56867.375000
# 80%       31.000000      0.384615      0.750000      0.188202   74914.470000
# 90%       40.000000      0.486486      0.833333      0.241717  157879.490000
# 99%       46.000000      0.621622      1.000000      0.313234  293257.545000
# max       46.000000      0.621622      1.000000      0.313234  293257.545000

# %%
# visualizing for next 20 columns
for cols in X_num.columns[20:40]:
    show_plots(X_num, cols)

# %% [markdown]
# #### Columnwise Observations
#
# - Columns v26,v27,v28,v29,v30,v31,v32,v33,v34,v40,v49,v50,v51 have outliers

# %%
columns_with_outlier_2 = ['v26','v27','v28','v29','v30','v31','v32','v33','v34','v40','v49','v50','v51']

# %%
# describing the numerical features percentile for last 16 numerical columns

X_num[num_features[40:]].describe(percentiles=[0.01,0.05,0.10,0.25,0.50,0.75,0.80,0.9,0.99])
# Out:
#                  v52            v53            v54            v55  \
# count   25356.000000   25356.000000   25356.000000   25356.000000
# mean    41682.066156   41685.524821   42375.259584    3086.029265
# std     57399.898498   57393.389688   57687.731831   41378.720771
# min        37.740215     -58.757503       0.000000 -195208.362900
# 1%         37.740215     -58.757503       0.000000 -195208.362900
# 5%        967.797147     891.294365    1204.057090  -45560.469392
# 10%      2047.296227    2043.136968    2456.024512  -20878.946985
# 25%      6030.284632    6012.173778    6642.111794   -5183.056787
# 50%     19916.991360   19916.360620   20581.220620    -287.490072
# 75%     41028.328665   41005.214303   41675.623452    7293.000873
# 80%     53630.505380   53821.073450   54956.269280   13401.119090
# 90%    117050.936350  116494.558900  117763.454950   47100.813875
# 99%    230426.560200  230491.551100  232594.526300  101325.250000
# max    230426.560200  230491.551100  232594.526300  101325.250000
#
#                  v56           v57           v58           v59           v60  \
# count   25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean    78675.855203      1.570672      1.404802      0.317551      0.534543
# std    101018.886777      1.287156      1.123252      0.127574      0.149937
# min       585.410603      0.062791      0.011565      0.000000      0.122807
# 1%        585.410603      0.062791      0.011565      0.000000      0.122807
# 5%       3284.966306      0.192999      0.151106      0.110156      0.250000
# 10%      6199.301964      0.348137      0.291613      0.161290      0.333333
# 25%     14886.514725      0.682658      0.624242      0.239130      0.454545
# 50%     42406.800080      1.275106      1.174613      0.319495      0.531250
# 75%     79904.287502      1.856361      1.686848      0.400000      0.642857
# 80%    103565.951900      2.175024      1.957275      0.423077      0.666667
# 90%    204813.694700      3.328200      2.943244      0.500000      0.727273
# 99%    424220.186000      5.663329      4.884180      0.568627      0.769231
# max    424220.186000      5.663329      4.884180      0.568627      0.769231
#
#                 v61           v62           v63           v64           v65  \
# count  25356.000000  25356.000000  25356.000000  25356.000000  25356.000000
# mean       0.261736      0.123266      0.506503      0.773140      0.459692
# std        0.306049      0.202833      0.230312      0.234860      0.248089
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 1%         0.000000      0.000000      0.000000      0.000000      0.000000
# 5%         0.000000      0.000000      0.142857      0.333333      0.072142
# 10%        0.000000      0.000000      0.250000      0.466667      0.171959
# 25%        0.000000      0.000000      0.372881      0.636364      0.298077
# 50%        0.166667      0.021622      0.500000      0.804348      0.433962
# 75%        0.400000      0.142857      0.614035      1.000000      0.577982
# 80%        0.500000      0.200000      0.666667      1.000000      0.636364
# 90%        0.750000      0.400000      0.857143      1.000000      0.883048
# 99%        1.000000      0.800000      1.000000      1.000000      0.985507
# max        1.000000      0.800000      1.000000      1.000000      0.985507
#
#                 v66           v67
# count  25356.000000  25356.000000
# mean       0.459692      2.798317
# std        0.248089      2.381061
# min        0.000000      0.000000
# 1%         0.000000      0.000000
# 5%         0.072142      0.000000
# 10%        0.171959      0.000000
# 25%        0.298077      1.000000
# 50%        0.433962      2.000000
# 75%        0.577982      4.000000
# 80%        0.636364      5.000000
# 90%        0.883048      7.000000
# 99%        0.985507      8.000000
# max        0.985507      8.000000

# %%
# visualizing for last 16 columns
for cols in X_num.columns[40:]:
    show_plots(X_num, cols)

# %%
columns_with_outlier_3 = ['v52','v53','v54','v55','v56','v57','v58','v60','v62','v63','v64']

# %%
# combining all the columns  containing outliers
all_columns_with_outlier = columns_with_outlier_1 + columns_with_outlier_2 + columns_with_outlier_3
len(all_columns_with_outlier)
# Out:
# 41

# %% [markdown]
# ### Outlier treatment

# %% [markdown]
#  From above distributions, we have got all the variables containing outliers in data.
#  now, we will write a function to calculate IQR for each variable and will cap the extremes with permitted values
#  lower_range = Q1 - (1.5 * IQR)
#  upper_range = Q3 + (1.5 * IQR)

# %%
# function to find boundaries for lower limit and upper limit
def find_boundaries(df, col, distance=1.5):

    '''Function will take dataframe and column name and will return upperlimit and lower limit'''
    # Let's calculate the boundaries outside which sit the outliers
    # for skewed distributions

    # distance passed as an argument, gives us the option to
    # estimate 1.5 times or 3 times the IQR to calculate
    # the boundaries.

    IQR = df[col].quantile(0.75) - df[col].quantile(0.25)

    lower_boundary = df[col].quantile(0.25) - (IQR * distance)
    upper_boundary = df[col].quantile(0.75) + (IQR * distance)

    return upper_boundary, lower_boundary

# %%
# for each outlier column in X_num
for cols in X_num[all_columns_with_outlier]:
    
    # get the upper range and lower range
    upper_range, lower_range = find_boundaries(X_num, cols)
    
    # Now let's replace the outliers by the maximum and minimum limit

    X_num[cols]= np.where(X_num[cols] > upper_range, upper_range,
                       np.where(X_num[cols] < lower_range, lower_range, X_num[cols]))
#     print (f"{cols}:upper_range:{upper_range}, lower_range:{lower_range}")

# %%
# checking if outliers are removed or not
for cols in X_num[all_columns_with_outlier]:
     show_plots(X_num, cols)

# %% [markdown]
# ### Observations
# - After applying Outlier censoring and capping, we can now see that there are no outliers present

# %% [markdown]
# # Feature Selection - Numerical Features

# %% [markdown]
# ## Removing features with zero variance

# %%
# checking shape of X_num before removing features with zero variance
X_num.shape
# Out:
# (25356, 56)

# %%
# removing features with Zero variance
from sklearn.feature_selection import VarianceThreshold
feature_selector = VarianceThreshold(threshold=0)
feature_selector.fit_transform(X_num)

# Calling variances_ to get the variance score generated for each feature
variance_list = feature_selector.variances_
# variance_list
# print(variance_list)
print(X_num.columns)

# get_support method will give indexes of columns being selected
cols = feature_selector.get_support(indices=True)
# cols
X_num_feature_after_VT = X_num.iloc[:,cols]
print(X_num_feature_after_VT.columns)
# Out:
# Index(['v2', 'v3', 'v4', 'v8', 'v9', 'v10', 'v11', 'v12', 'v14', 'v15', 'v16',
#        'v17', 'v18', 'v19', 'v20', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26',
#        'v27', 'v28', 'v29', 'v30', 'v31', 'v32', 'v33', 'v34', 'v35', 'v36',
#        'v37', 'v38', 'v39', 'v40', 'v41', 'v42', 'v49', 'v50', 'v51', 'v52',
#        'v53', 'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v60', 'v61', 'v62',
#        'v63', 'v64', 'v65', 'v66', 'v67'],
#       dtype='object')
# Index(['v2', 'v3', 'v4', 'v8', 'v9', 'v10', 'v11', 'v14', 'v15', 'v16', 'v17',
#        'v18', 'v19', 'v20', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27',
#        'v28', 'v29', 'v30', 'v31', 'v32', 'v33', 'v34', 'v35', 'v36', 'v37',
#        'v38', 'v39', 'v40', 'v41', 'v42', 'v49', 'v50', 'v51', 'v52', 'v53',
#        'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v60', 'v61', 'v62', 'v63',
#        'v64', 'v65', 'v66', 'v67'],
#       dtype='object')

# %%
# Checking the shape of data after  removing feature with zero variance
X_num_feature_after_VT.shape
# Out:
# (25356, 55)

# %% [markdown]
# #### Observations
# - From above we can observe that one feature got removed from X_num
# - v12 is the removed feaature

# %% [markdown]
# ## Selecting K-Best Features

# %%
# We will further reduce our feature space by selecting  30 features (p.s - we can take any number of feature)
# for this purpose selectKBest can be used 

from sklearn.feature_selection import SelectKBest, f_classif
selector = SelectKBest(f_classif, k=30)
selector.fit_transform(X_num_feature_after_VT, y)

# Get columns to keep and create new dataframe with those only
cols = selector.get_support(indices=True)
X_select_features_num = X_num_feature_after_VT.iloc[:,cols]

# showing feature importance score  generated by SelectkBest in descending order
feature_importances_=pd.DataFrame(selector.scores_,
                                 index=X_num_feature_after_VT.columns,
                                 columns=['importance']).sort_values('importance',ascending=False)
print(feature_importances_)
# Out:
#      importance
# v8   775.643760
# v9   770.762978
# v2   747.611993
# v10  704.125513
# v58  553.924088
# v57  536.390017
# v26  488.395068
# v27  470.164965
# v40  413.950593
# v20  361.653428
# v55  333.313680
# v64  322.199443
# v19  320.827620
# v17  316.283734
# v29  308.372725
# v28  278.341182
# v62  269.755489
# v4   253.701185
# v50  252.226657
# v31  245.232055
# v41  214.680175
# v15  212.935183
# v22  209.816511
# v52  205.316954
# v53  198.383372
# v32  193.471304
# v11  184.767119
# v3   184.625097
# v54  182.522213
# v51  178.160582
# v21  178.118371
# v30  163.911239
# v33  161.804822
# v67  136.497909
# v14  121.045542
# v18  113.694907
# v35  108.500902
# v38  101.654775
# v37   99.412684
# v56   99.310399
# v34   94.731547
# v25   89.080202
# v61   79.770239
# v36   78.072081
# v42   77.954291
# v23   74.650626
# v65   61.317013
# v66   61.317013
# v39   53.766005
# v63   47.428423
# v59   38.374828
# v60   20.714686
# v24   19.879946
# v49    4.992315
# v16    0.134189

# %%
## Function to plot the feature importance
def plot_feature_importance(df):
    ''' Function will take input as feature importance dataframe and will plot the feature importance in descending order'''
    
    # define figure size
    plt.figure(figsize=(20, 8))
    
    # plot the scores
    sns.barplot(x=df.index,y='importance',data=df,order=df.sort_values('importance',ascending=False).index)

    # set labels
    plt.xlabel("Feature", size=15)
    plt.ylabel("Score", size=15)
    plt.title("Feature v/s Score (Feature Importance)")

# %%
# Plotting feature importance obtained from SelectKBest
plot_feature_importance(feature_importances_)

# %%
print(X_select_features_num.columns)
# Out:
# Index(['v2', 'v3', 'v4', 'v8', 'v9', 'v10', 'v11', 'v15', 'v17', 'v19', 'v20',
#        'v22', 'v26', 'v27', 'v28', 'v29', 'v31', 'v32', 'v40', 'v41', 'v50',
#        'v51', 'v52', 'v53', 'v54', 'v55', 'v57', 'v58', 'v62', 'v64'],
#       dtype='object')

# %%
X_select_features_num.shape
# Out:
# (25356, 30)

# %% [markdown]
# # Feature selection - Categorical Features

# %%
X_cat.shape
# Out:
# (25356, 5)

# %% [markdown]
# - Since there are only few categorical features , we will consider all the categorical features for our model

# %% [markdown]
# # Creating the Master Feature Set for Model Development

# %%
# Creating a master feature set combining all the selected numerical features and categorical features
X_all=pd.concat([X_select_features_num,X_cat],axis=1,join="inner")
X_all.shape
# Out:
# (25356, 35)

# %%
# Checking the value counts in our target variable
y['y'].value_counts()
# Out:
# 0    23858
# 1     1498
# Name: y, dtype: int64

# %% [markdown]
# # Splitting the dataset in training and testing

# %%
# Splitting the dataset into 80:20 ratio 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_all, y, test_size=0.2, random_state=10)

# %%
print("Shape of Training Data",X_train.shape)
print("Shape of Testing Data",X_test.shape)
print("Response Rate in Training Data",y_train.mean())
print("Response Rate in Testing Data",y_test.mean())
# Out:
# Shape of Training Data (20284, 35)
# Shape of Testing Data (5072, 35)
# Response Rate in Training Data y    0.059012
# dtype: float64
# Response Rate in Testing Data y    0.059345
# dtype: float64

# %% [markdown]
# ### Handling Imbalance data by doing random oversampling

# %%
# Since we have very less no. of minority sample, we will handle this imbalance by doing oversampling of minority class
# The class can be defined and takes a sampling_strategy argument that can be set to “minority” to automatically balance the minority class with majority class 

from imblearn.over_sampling import RandomOverSampler
# define oversampling strategy
oversample = RandomOverSampler(sampling_strategy='minority')
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X_train, y_train)

# %%
X_over.shape
# Out:
# (38174, 35)

# %%
y_over.value_counts()
# Out:
# y
# 1    19087
# 0    19087
# dtype: int64

# %% [markdown]
# ### Basis for selecting  classification model
# - Non Linearity in feature relationships are observed which makes tree methods a good choice
# - There are few options to consider among tree methods
#      - White Box (Completely Explainable Set of Rules) - Decision Tree
#      - Ensemble Methods - Random Forest (With Bagging)
#      - Ensemble Methods - GBM/XGBoost (Boosting)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Define a function for modeling and cross-validation
# This function will do the following:
#
# - fit the model
# - determine training AUC
# - perform CV is performCV is True
# - plot Feature Importance if printFeatureImportance is True

# %%
def modelfit(alg, d_x_train, d_y_train, performCV=True, printFeatureImportance=True, cv_folds=5):
    '''input parameters:
        alg - model
        d_x_train - independent features dataframe
        d_y_train - dependent feature dataframe
        performCV - flag to perform cross validation , default = True
        printprintFeatureImportance- flag to print feature importance, default=True
        cv_folds - Number of cross validation to perform
    '''
    
    #Fit the algorithm on the data
    alg.fit(d_x_train ,d_y_train )
        
    #Predict training set:
    dtrain_predictions = alg.predict(d_x_train)
    dtrain_predprob = alg.predict_proba(d_x_train)[:,1]
    
    #Perform cross-validation:
    if performCV:
        cv_score = cross_val_score(alg, d_x_train, d_y_train, cv=cv_folds, scoring='roc_auc')
    
    #Print model report:
    print ("\nModel Report")
    print ("Accuracy : %.4g" % metrics.accuracy_score(d_y_train.values, dtrain_predictions))
    print ("AUC Score (Train): %f" % metrics.roc_auc_score(d_y_train, dtrain_predprob))
    
    if performCV:
        print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
                
    #Print Feature Importance:
    if printFeatureImportance:
        feature_importance=pd.DataFrame(alg.feature_importances_,
                                 index=d_x_train.columns,
                                 columns=['importance']).sort_values('importance',ascending=False)
        plot_feature_importance(feature_importance)
        plt.ylabel('Feature Importance Score')

# %% [markdown]
# ### Building a decision tree model

# %%
# Building a Decision Tree Model
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier(criterion='gini',random_state=10)
modelfit(dtree, X_train,y_train,printFeatureImportance=False)
# Out:
# Model Report
# Accuracy : 1
# AUC Score (Train): 1.000000
# CV Score : Mean - 0.5517219 | Std - 0.01065934 | Min - 0.5380977 | Max - 0.5700327

# %% [markdown]
# ### Building a random forest model

# %%
from sklearn.ensemble import RandomForestClassifier
rf0 = RandomForestClassifier(random_state=10)
modelfit(rf0, X_train,y_train)
# Out:
# Model Report
# Accuracy : 1
# AUC Score (Train): 1.000000
# CV Score : Mean - 0.7577363 | Std - 0.02479001 | Min - 0.7398702 | Max - 0.8065251

# %% [markdown]
# ### Building a gradient boost model

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbm0 = GradientBoostingClassifier(random_state=10)
modelfit(gbm0, X_train,y_train)
# Out:
# Model Report
# Accuracy : 0.9467
# AUC Score (Train): 0.853316
# CV Score : Mean - 0.781376 | Std - 0.02276005 | Min - 0.7604876 | Max - 0.8246164

# %% [markdown]
# # Model Evaluation

# %%
# Calculating predict and predict_proba for all the above models

y_pred_tree=dtree.predict(X_test)
y_pred_tree_proba = dtree.predict_proba(X_test)[:,1]
y_pred_rf=rf0.predict(X_test)
y_pred_rf_proba = rf0.predict_proba(X_test)[:,1]
y_pred_gbm=gbm0.predict(X_test)
y_pred_gbm_proba = gbm0.predict_proba(X_test)[:,1]

# %%
# function to show Accuracy, Precision, Recall and F1-Score
def show_validation_scores(model_name,y_test,y_pred):
    '''Function will take model_name, y_test and y_pred(corresponding to each model ) as input '''
    print (f"Scores for {model_name};")
    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
    print("Precision:",metrics.precision_score(y_test,y_pred))
    print("Recall:",metrics.recall_score(y_test,y_pred))
    print("f1_score:",metrics.f1_score(y_test,y_pred))

# %%
# Function to show and plot roc_curve
def plot_roc_curve(Y_test, model_probs):
    
    '''Input to the function is Y_test and Y_pred_proba'''
    random_probs = [0 for _ in range(len(Y_test))]
     # calculate AUC
    model_auc = roc_auc_score(Y_test, model_probs)
     # summarize score
    print('Model: ROC AUC=%.3f' % (model_auc))
     # calculate ROC Curve
      # For the Random Model
    random_fpr, random_tpr, _ = roc_curve(Y_test, random_probs)
      # For the actual model
    model_fpr, model_tpr, _ = roc_curve(Y_test, model_probs)
     # Plot the roc curve for the model and the random model line
    plt.plot(random_fpr, random_tpr, linestyle='--', label='Random')
    plt.plot(model_fpr, model_tpr, marker='.', label='Model')
     # Create labels for the axis
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
     # show the legend
    plt.legend()
     # show the plot
    plt.show()

# %% [markdown]
# ### Evaluating Decision Tree Model

# %%
# Evaluating Decision Tree
show_validation_scores("Decision Tree",y_test,y_pred_tree)
# Out:
# Scores for Decision Tree;
# Accuracy: 0.8919558359621451
# Precision: 0.1724137931034483
# Recall: 0.2159468438538206
# f1_score: 0.19174041297935104

# %%
# plotting confusion matrix

metrics.plot_confusion_matrix(dtree,X_test,y_test)

# %%
# plotting roc curve for decision tree
plot_roc_curve(y_test,y_pred_tree_proba)
# Out:
# Model: ROC AUC=0.575

# %% [markdown]
# ### Evaluating Random Forest Model

# %%
# Evaluating Random Forest model 
show_validation_scores("Random Forest",y_test,y_pred_rf)
# Out:
# Scores for Random Forest;
# Accuracy: 0.9406545741324921
# Precision: 0.5
# Recall: 0.009966777408637873
# f1_score: 0.01954397394136808

# %%
metrics.plot_confusion_matrix(rf0,X_test,y_test)

# %%
# plotting roc curve for random forest tree
plot_roc_curve(y_test,y_pred_rf_proba)
# Out:
# Model: ROC AUC=0.788

# %% [markdown]
# ### Evaluating Gradient Boost Model

# %%
# Evaluating Gradient Boost model 
show_validation_scores("Gradient Boost",y_test,y_pred_gbm)
# Out:
# Scores for Gradient Boost;
# Accuracy: 0.9394716088328076
# Precision: 0.43478260869565216
# Recall: 0.0664451827242525
# f1_score: 0.11527377521613832

# %%
# plotting confusion matrix
metrics.plot_confusion_matrix(gbm0,X_test,y_test)

# %%
# plotting roc curve for gradient boosting model
plot_roc_curve(y_test,y_pred_gbm_proba)
# Out:
# Model: ROC AUC=0.799

# %% [markdown]
# ## Observations
#
# - From above we can observe that The GBM Model has outperformed the decision tree and random forest model (wrt to all the evaluation parameters)
# - We will further tune GBM Hyperparameters to improve on precision and recall

# %% [markdown]
# # Hyperparameter tuning of GBM Model

# %% [markdown]
# GBM Model consist of Two types of parameter :
# 1. Tree Specific Parameters
# 2. Boosting Specific Parameters

# %% [markdown]
# - Tree-Specific parameters
#     - Tree-specific parameters
#     - min_samples_split
#     - min_samples_leaf
#     - max_depth
#     - min_leaf_nodes
#     - max_features
#
#
#
# - Boosting Specific Parameters
#     - learning rate
#     - n-estimators
#     - subsample

# %% [markdown]
# ### Finding No. of estimators for higher learning rate

# %%
# min_samples_split = 150 : ~0.5-1% of total values. Since this is imbalanced class problem, we'll take small value
# min_samples_leaf = 50 : Just using for preventing overfitting. will be tuned later.
# max_depth = 8 : initializing 
# max_features = 'sqrt' : general thumbrule to start with
# subsample = 0.8 : typically used value (will be tuned later)
# learning_rate = 0.05

from sklearn.model_selection import GridSearchCV
param_test1 = {'n_estimators':range(20,81,10)}
gsearch1 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.05, min_samples_split=150,
                                  min_samples_leaf=50,max_depth=8,max_features='sqrt', subsample=0.8,random_state=10), 
                       param_grid = param_test1, scoring='roc_auc',n_jobs=-1, cv=5,verbose=2)
gsearch1.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   max_depth=8,
#                                                   max_features='sqrt',
#                                                   min_samples_leaf=50,
#                                                   min_samples_split=150,
#                                                   random_state=10,
#                                                   subsample=0.8),
#              n_jobs=-1, param_grid={'n_estimators': range(20, 81, 10)},
#              scoring='roc_auc', verbose=2)

# %%
 gsearch1.best_params_, gsearch1.best_score_
# Out:
# ({'n_estimators': 80}, 0.784650223324453)

# %% [markdown]
# ## Tuning tree parameters

# %%
#Performing grid search to find max_depth and min_samples_split
param_test2 = {'max_depth':range(5,16,2), 'min_samples_split':range(200,1001,200)}
gsearch2 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=80,
                                                max_features='sqrt', subsample=0.8, random_state=10), 
                       param_grid = param_test2, scoring='roc_auc',n_jobs=-1, cv=5,verbose=1)
gsearch2.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   max_features='sqrt',
#                                                   n_estimators=80,
#                                                   random_state=10,
#                                                   subsample=0.8),
#              n_jobs=-1,
#              param_grid={'max_depth': range(5, 16, 2),
#                          'min_samples_split': range(200, 1001, 200)},
#              scoring='roc_auc', verbose=1)

# %%
 gsearch2.best_params_, gsearch2.best_score_
# Out:
# ({'max_depth': 5, 'min_samples_split': 600}, 0.7873523296004008)

# %%
# Performing grid search to find min_samples_split and min_samples_leaf
param_test3 = { 'min_samples_leaf':range(30,71,10)}
gsearch3 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=80,max_depth=5,
                                                    min_samples_split=600,max_features='sqrt', subsample=0.8, random_state=10), 
                       param_grid = param_test3, scoring='roc_auc',n_jobs=-1, cv=5, verbose=2)
gsearch3.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   max_depth=5,
#                                                   max_features='sqrt',
#                                                   min_samples_split=600,
#                                                   n_estimators=80,
#                                                   random_state=10,
#                                                   subsample=0.8),
#              n_jobs=-1, param_grid={'min_samples_leaf': range(30, 71, 10)},
#              scoring='roc_auc', verbose=2)

# %%
gsearch3.best_params_, gsearch3.best_score_
# Out:
# ({'min_samples_leaf': 40}, 0.7884779068535238)

# %%
modelfit(gsearch3.best_estimator_, X_train, y_train)
# Out:
# Model Report
# Accuracy : 0.9438
# AUC Score (Train): 0.843456
# CV Score : Mean - 0.7884779 | Std - 0.01865199 | Min - 0.7735978 | Max - 0.8251184

# %%
#Grid seach on max_features
param_test4 = {'max_features':range(7,20,2)}
gsearch4 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=80,max_depth=5,
                                                   min_samples_split=600, min_samples_leaf=40, max_features='sqrt', subsample=0.8, random_state=10), 
                       param_grid = param_test4, scoring='roc_auc',n_jobs=-1, cv=5, verbose=2)
gsearch4.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   max_depth=5,
#                                                   max_features='sqrt',
#                                                   min_samples_leaf=40,
#                                                   min_samples_split=600,
#                                                   n_estimators=80,
#                                                   random_state=10,
#                                                   subsample=0.8),
#              n_jobs=-1, param_grid={'max_features': range(7, 20, 2)},
#              scoring='roc_auc', verbose=2)

# %%
gsearch4.best_params_, gsearch4.best_score_
# Out:
# ({'max_features': 15}, 0.7874576170810617)

# %% [markdown]
# ### Tuning sub-sample and lowering the learning rate

# %%
#Grid seach on subsample and max_features
param_test5 = param_test5 = {'subsample':[0.6,0.7,0.75,0.8,0.85,0.9]}
gsearch5 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=80,max_depth=5,
                                                   min_samples_split=600, min_samples_leaf=40, max_features=15, subsample=0.8, random_state=10), 
                       param_grid = param_test5, scoring='roc_auc',n_jobs=-1, cv=5, verbose=2)
gsearch5.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   max_depth=5, max_features=15,
#                                                   min_samples_leaf=40,
#                                                   min_samples_split=600,
#                                                   n_estimators=80,
#                                                   random_state=10,
#                                                   subsample=0.8),
#              n_jobs=-1,
#              param_grid={'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9]},
#              scoring='roc_auc', verbose=2)

# %%
gsearch5.best_params_, gsearch5.best_score_
# Out:
# ({'subsample': 0.85}, 0.7876175144216571)

# %%
gbm_tuned_1 = GradientBoostingClassifier(learning_rate=0.05, n_estimators=80,max_depth=5,
                                                   min_samples_split=600, min_samples_leaf=40, max_features=15, subsample=0.85, random_state=10)
modelfit(gbm_tuned_1, X_train, y_train)
# Out:
# Model Report
# Accuracy : 0.9449
# AUC Score (Train): 0.851167
# CV Score : Mean - 0.7876175 | Std - 0.02078745 | Min - 0.7675238 | Max - 0.8276177

# %%
gbm_tuned_2 = GradientBoostingClassifier(learning_rate=0.01, n_estimators=400,max_depth=5,
                                                   min_samples_split=600, min_samples_leaf=40, max_features=15, subsample=0.85, random_state=10)
modelfit(gbm_tuned_2, X_train, y_train)
# Out:
# Model Report
# Accuracy : 0.945
# AUC Score (Train): 0.852050
# CV Score : Mean - 0.7880867 | Std - 0.02012802 | Min - 0.7705819 | Max - 0.8274872

# %%
gbm_tuned_3 = GradientBoostingClassifier(learning_rate=0.005, n_estimators=800,max_depth=5,
                                                   min_samples_split=600, min_samples_leaf=40, max_features=15, subsample=0.85, random_state=10)
modelfit(gbm_tuned_3, X_train, y_train)
# Out:
# Model Report
# Accuracy : 0.945
# AUC Score (Train): 0.853180
# CV Score : Mean - 0.7877374 | Std - 0.01976628 | Min - 0.7690537 | Max - 0.8260337

# %% [markdown]
# # Evaluating Tuned GBM model on test data

# %%
y_pred_gbm_tuned=gbm_tuned_3.predict(X_test)
y_pred_gbm_tuned_proba = gbm_tuned_3.predict_proba(X_test)[:,1]

# %%
show_validation_scores("Gradient Boost",y_test,y_pred_gbm_tuned)
# Out:
# Scores for Gradient Boost;
# Accuracy: 0.9406545741324921
# Precision: 0.5
# Recall: 0.03986710963455149
# f1_score: 0.07384615384615384

# %%
metrics.plot_confusion_matrix(gbm_tuned_3,X_test,y_test)

# %%
plot_roc_curve(y_test,y_pred_gbm_proba)
# Out:
# Model: ROC AUC=0.799

# %% [markdown]
# # Conclusion
# - The GBM Model has outperformed the decision tree and random forest model (wrt to all the evaluation parameters). we can use GBM model for our purpose
# - We will build a Business Value Metric based on the features selected by GBM
